# %%
import pandas as pd

# %%
df = pd.read_csv("Viva_Schedule.csv", sep=';')

# %%
df.head(2)
# Out:
#    Applicants_Subject_Code       Roll Invoice          Applicants_Name  \
# 0                      201  201000088  BQKOIZ  MD.KABIR HOSSAIN SIKDER
# 1                      201  201000326  FXLULU        MD. EMRAN HOSSAIN
#
#                       name              father        mother         dob  \
# 0  MD.KABIR HOSSAIN SIKDER  MD.A. LATIF SIKDER  KULSUM BEGUM  1989-10-05
# 1        MD. EMRAN HOSSAIN   A. SALAM HOWLADER  HENARA BEGUM  1997-10-03
#
#   homedistrict   Viva_Date Viva_Time
# 0     Barishal  2019-11-11  10:00:00
# 1     Barishal  2019-11-11  10:00:00

# %%
name = list(df["Applicants_Name"])

# %%
for i in range(len(df)):
    if ("arafat" in str(df["Applicants_Name"].iloc[i]).lower()) and (df["":
        print(df.iloc[i])
# Out:
# Applicants_Subject_Code                 202
# Roll                              202006012
# Invoice                              PODHRB
# Applicants_Name             MD EASIN ARAFAT
# name                        MD EASIN ARAFAT
# father                     SHAIKH ALI AHMED
# mother                         NASRIN AKTER
# dob                              1996-11-01
# homedistrict                       Bagerhat
# Viva_Date                        2019-11-12
# Viva_Time                          10:00:00
# Name: 487, dtype: object
# Applicants_Subject_Code                202
# Roll                             202010810
# Invoice                             HCPZDY
# Applicants_Name                 ARAFAT ALI
# name                            ARAFAT ALI
# father                     MD. ABDUS SAMAD
# mother                       ALEKJAN BEGUM
# dob                             1997-06-06
# homedistrict                      Habiganj
# Viva_Date                       2019-11-12
# ...

# %%
s = "ABC"

s.lower
